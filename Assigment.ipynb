# %% [markdown]
# # Week 6 Assignment

# %% [markdown]
# ## Intro:
#
# This week we will start learning about the standard ASIC methodology.
#
# This weeks tasks will be focused on getting you oriented toward the new tools as well as giving you some familiarity with the simumaltion and synthesis tools we are using.
#
# As usual, source the setup.sh scipt before getting started.
