# %% [markdown]
# # Week 6 Assignment

# %% [markdown]
# ## Intro:
#
# This week we will start learning about the standard ASIC methodology.
#
# This week's tasks will be focused on getting you oriented toward the tools we will be using for synthesis (Genus) and place and route (Innovus).
#
# As usual, source the setup.sh scipt before getting started.

# %% [markdown]
# # Part 1 - Synthesis
#
# For this part, you will run through a Rapid Adoption kit from Cadence.  It sort of assumes you have some familiarity with synthesis already, so some of it may seem a bit disconnected.  The RAKs can't be distributed, so the important bits are linked to your "labs" folder by the setup script.

# %% [markdown]
# ## Deliverable 1
#
# Read through the Genus RAK documented linked from Canvas.  cd to labs/genus/LAB1
#
# Work through the RAK paying attention to the types of commands available to you and the general flow used by the lab.  This will be the foundation for our own synthesis work next week.
#
# Complete LAB1 and LAB2.  You can run through LAB3 if you'd like.  It adds some low power optimization to the flow.  We may use some of this, although it isn't really a primaray consideration at this pont.
#
# When you have completed parts 1 and 2, submit the final timing report from each run to canvas.

# %% [markdown]
# ## Deliverable 2
#
# Find the worst critical path in either file.
#
# Now look at the associated RTL.  Trace the path show in the timing report and trace it through the rtl.
#
# Describe the path below.  A few tips...
#
# 1) It is sometimes easiest to get started by using grep from the command line to find where to start.  For eaxmple - where is the dsp core instantiated?  `grep -i tdsp_core RTL/*.v` will show you places where the string appears.
# 1) I recognize that you don't necessarily know Verilog, but it's not that hard...
#
# I turns out that, as mundane as this seems, it is a critical skill because you frequently need to change the RTL in order to meet timing.  Being able to quickly locate the offending logic is essential!
#
# ------------------------------------------
# Describe the path here.

# %% [markdown]
# # Part 2 Floorplanning.
#
# There is another RAK pertaining to Floorplanning using Innovus.  This is the subject of this section.

# %% [markdown]
# ## Deliverable 3
#
# Go through the floorplanning RAK linked from the assignment page (this will take some time).
#
# Submit a screenshot of the final floorplan when you are done.
#
# (Note: - I am going through this too.  Keep an eye on Slack to see if I encounter any issues...)
